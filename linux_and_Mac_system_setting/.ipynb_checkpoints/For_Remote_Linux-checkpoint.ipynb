# %%
# %%bash
# ls
# Out:
# For_Remote_Linux.ipynb
# Untitled.ipynb

# %%
pwd
# Out:
# '/home/gao/Desktop/Code'

# %%
# %%bash
#
# which python

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash

# %%
# %%bash
